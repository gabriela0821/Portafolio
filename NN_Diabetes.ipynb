# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriela0821/Portafolio/blob/main/NN_Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Camilo Gomez y Gabriela Lara

# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import numpy as np


datosauxd = pd.read_excel('diabetes (1).xlsx')
print(datosauxd)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
plt.scatter(datosauxd["Pregnancies"],datosauxd["Outcome"])

# %%
plt.scatter(datosauxd["BloodPressure"],datosauxd["Outcome"])

# %%
plt.scatter(datosauxd["Glucose"],datosauxd["Outcome"])

# %%
plt.scatter(datosauxd["SkinThickness"],datosauxd["Outcome"])

# %%
plt.scatter(datosauxd["Insulin"],datosauxd["Outcome"])

# %%
plt.scatter(datosauxd["BMI"],datosauxd["Outcome"])

# %%
plt.scatter(datosauxd["DiabetesPedigreeFunction"],datosauxd["Outcome"])

# %%
plt.scatter(datosauxd["Age"],datosauxd["Outcome"])

# %%
Mcorrelacion=datosauxd.corr()
print(Mcorrelacion)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
dtxd= datosauxd[[ 'Glucose','BloodPressure' ,'Insulin','BMI','DiabetesPedigreeFunction',"Outcome"]]


plt.scatter(dtxd["Glucose"],dtxd["BloodPressure"],dtxd["BMI"],dtxd["Insulin"] )

# %%
plt.scatter(dtxd["Glucose"],dtxd["BloodPressure"],dtxd["BMI"],dtxd["Outcome"] )

# %%
plt.scatter(dtxd["Glucose"],dtxd["Insulin"],dtxd["BMI"],dtxd["DiabetesPedigreeFunction"] )

# %%
x=dtxd= datosauxd[[ 'Glucose','Insulin','BMI','DiabetesPedigreeFunction']]
y=dtxd= datosauxd[[ 'Outcome']]

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(10,8,20))

# %%
clf.fit(x,y)
c=clf.n_layers_
d=clf.coefs_
#print(c)
#print(d)
contandor=0
for i in d:
  print('coeficientes de la capa numero',contandor)
  print(len(i))
  print(i)
  contandor=contandor+1
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# coeficientes de la capa numero 0
# 4
# [[-0.29796868 -0.52074015 -0.33504226  1.389299   -0.18104923 -1.08460816
#   -1.2966503   0.25223913 -0.44841684 -0.81762766]
#  [-0.27094571 -0.4043638  -0.15276054  0.45315683 -0.23164278  0.54853857
#   -0.30794844  0.32470042  0.0171657  -0.14962218]
#  [ 0.10024496 -0.07845132  0.59351524  0.09769864 -0.33418545 -0.53574464
#    0.20277044 -0.99335984  0.57968484 -0.60847333]
#  [ 0.41856869  0.40101497 -0.50225961  0.17972188  0.58738551  0.4274163
#    0.15004664  0.59012156  0.44474574  0.29321396]]
# coeficientes de la capa numero 1
# 10
# [[-0.11256785 -0.21416815 -0.39161899 -0.28307425  0.00483767  0.27235094
#    0.31307686 -0.42367949]
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, stratify=y,train_size=0.7,)

clf = MLPClassifier(#random_state=1, 
                    max_iter=100).fit(X_train, y_train)
#paso de 100
clf.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.6320346320346321
